# %% [markdown]
# <a href="https://colab.research.google.com/github/farhankhan19032003-lgtm/expoloratory-data-analysis/blob/main/STATISTICS_DATA_SCIENCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
MEAN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ar=np.array([10,9,8,7,6,11,24,200,600,10])

# %%
np.sum(ar)/len(ar)
# Out:
# np.float64(88.5)

# %%
len(ar)
# Out:
# 10

# %%
np.sort(ar)
# Out:
# array([  6,   7,   8,   9,  10,  10,  11,  24, 200, 600])

# %%
np.mean(ar)
# Out:
# np.float64(88.5)

# %%
import seaborn as sns

# %%
dataset=sns.load_dataset("titanic")
dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
dataset["age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
np.mean(dataset["age"])
# Out:
# np.float64(29.69911764705882)

# %%
np.mean(dataset["fare"])
# Out:
# np.float64(32.204207968574636)

# %%
sns.histplot(x="age",data=dataset)
plt.show()

# %%
sns.histplot(x="age",data=dataset,bins=[i for i in range(0,80,10)])
plt.show()

# %%
mn=np.mean(dataset["age"])

# %%
sns.histplot(x="age",data=dataset,bins=[i for i in range(0,81,10)])
plt.plot([mn for i in range(0,300)],[i for i in range(0,300)],c="yellow")

# %% [markdown]
# MEDIAN

# %%
np.median(dataset["fare"])
# Out:
# np.float64(14.4542)

# %%
dataset["age"].fillna(dataset["age"].mean(),inplace=True)
# Out:
# /tmp/ipython-input-3170167123.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["age"].fillna(dataset["age"].mean(),inplace=True)

# %%
np.median(dataset["age"])
# Out:
# np.float64(29.69911764705882)

# %%
dataset["age"].median()
# Out:
# 29.69911764705882

# %%
dataset["fare"].mean()
# Out:
# np.float64(32.204207968574636)

# %%
mn = np.mean(dataset["fare"])

# %%
sns.histplot(x="fare",data=dataset,bins=[i for i in range(0,81,10)])
plt.plot([mn for i in range(0,300)],[i for i in range(0,300)],c="red")
plt.plot([md for i in range(0,300)],[i for i in range(0,300)],c="yellow")

# %% [markdown]
# Mode

# %%
dataset["fare"].mode()[0]
# Out:
# np.float64(8.05)

# %%
dataset["fare"].value_counts()
# Out:
# fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 13.8583     1
# 50.4958     1
# 5.0000      1
# 9.8458      1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %%
mo=dataset["fare"].mode()[0]

# %%
sns.histplot(x="fare",data=dataset,bins=[i for i in range(0,81,10)])
plt.plot([mn for i in range(0,300)],[i for i in range(0,300)],c="red",label="mean")
plt.plot([md for i in range(0,300)],[i for i in range(0,300)],c="blue",label="median")
plt.plot([mo for i in range(0,300)],[i for i in range(0,300)],c="yellow",label="mode")
plt.legend()
plt.show()

# %% [markdown]
# measurement of variability

# %% [markdown]
# # ***RANGE***

# %%
dataset["age"].min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2506766695.py in <cell line: 0>()
# ----> 1 dataset["age"].min()
#
# ...

# %%
dataset["age"].max()
# Out:
# 80.0

# %%
min_r=dataset["age"].min()
max_r=dataset["age"].max()

# %%
min_r,max_r
# Out:
# (0.42, 80.0)

# %%
range=max_r-min_r

# %%
range
# Out:
# 79.58

# %%
var=sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
min_r=var("total_bill").min()
max_r=var("total_bill").min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2478253568.py in <cell line: 0>()
# ----> 1 min_r=var("total_bill").min()
#       2 max_r=var("total_bill").min()
#
# TypeError: 'DataFrame' object is not callable

# %%
import matplotlib.pyplot as plt
